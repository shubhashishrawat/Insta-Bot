# %% [markdown]
# # Ques 1: Login to your Instagram Handle
#
#          -> Submit with sample username and password

# %%
# Solution 1 ****Login to your Instagram Handle******* :-

from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module
#function for login
def login(driver):
    
    # go to instagram login page using .get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output http://localhost:8888/notebooks/Desktop/New%20folder/InstaBot-1%20Final%20.ipynb#Ques-2-1)-Type-for-%E2%80%9Cfood%E2%80%9D-in-search-bar-and-print-all-the-names-of-the-Instagram-Handles-that-are-displayed-in-list-after-typing-%E2%80%9Cfood%E2%80%9Daagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people follow you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec

# using geckodriver(FireFox web driver name) to remote the window please use the path for geckodriver as per your system
# here geckodriver is within anaconda so I write it straight forward
driver=webdriver.Firefox(executable_path='geckodriver')
# calling login function
login(driver)

# %% [markdown]
# # Ques 2 1) Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”
#
#     Note : Make sure to avoid printing hashtags

# %%
# *******solution 2 1)  Type for “food” in search bar and print all the names of the Instagram Handles that are displayed in list after typing “food”******


from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module
#function for login
def handlenames(driver):
    
    # go to instagram login page using .get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people follow you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
    # pass the word "food" in the search box to print the insatgrams handle
    # to locate the search box using the class name of the search box having the class name "XTCLo.x3qfX"
    search_bar=driver.find_element_by_class_name('XTCLo.x3qfX')
    # passing the word "food" in the search box usnig the .send_keys fun
    search_bar.send_keys('food')
    # wait for some time so that all the handles can be loaded
    time.sleep(2)
    # to get the names of driver 
    # locate the names of insta handle having the class name "Ap253"
    names=driver.find_elements_by_class_name('Ap253')
    # not printing the hastags 
    for i in names:
        if '#' not in i.text:
            print(i.text)

# using geckodriver(FireFox web driver name) to remote the window please use the path for geckodriver as per your system
# here geckodriver is within anaconda so I write it straight forward
driver=webdriver.Firefox(executable_path='geckodriver')
# calling login function
handlenames(driver)
# Out:
# foodtalkindia
# foodnetwork
# foodandwine
# foodgod
# dilsefoodie
# foodi_eshoodie
# food
# khau_gali_foodie
# iamdatingfood
# netflixfood
# foodie_incarnate
# foodiesince96
# foodnetworkkitchen
# buzzfeedfood
# fooddreamer
# foodies_street__
# dillifoodies
# foodbaby27
# meghnasfoodmagic
# bbcfood
# foodinsider
# foodategram
# foodscrafts
# food_dips
# foodnnja
# questlovesfood
# rajshrifood
# food_india24
# food_and_favourites
# food_home_by_mom1985
# _foodie___soul_
# eatlikeamaniac
# keralafoodrepost
# dcfoodporn
# foodies_v3
# foodyummazing
# yourfoodlab
# food_branthan
# foodyypreneur
# mumbaifoodie
# foodgasm98
# cookhouseby_stephy
# kerala_foodie__
# food.forfunsies
# foodinhands
# wifey.food.vibes
# thelickingsunrise
# harrodsfood
# pinch_of_flavours
# foodiepanda___
# foodyoucaneat
# salonikukreja

# %% [markdown]
# # Ques 2 1)Searching and Opening a profile using
#
#     Open profile of “So Delhi”

# %%
# ******code for Searching and Opening a profile using  function*******


from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module
#function for login
def SoDelhipage(driver):
    
    # go to instagram login page using .get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people follow you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
    # pass the word "food" in the search box to print the insatgrams handle
    # to locate the search box using the class name of the search box having the class name "XTCLo.x3qfX"
    search_bar=driver.find_element_by_class_name('XTCLo.x3qfX')
    # passing the word "food" in the search box usnig the .send_keys fun
    search_bar.send_keys('So Delhi')
    # wait for some time so that all the handles can be loaded
    time.sleep(2)
    # to get the names of driver 
    # locate the names of insta handle having the class name "Ap253"
    # find the required handle from the search result although its on the top but for worst case
    names=driver.find_elements_by_class_name('Fy4o8')
    for i in names:
        if i.text=='So Delhi':
            # clicking on the handle to open it
            i.click()

# using geckodriver(FireFox web driver name) to remote the window please use the path for geckodriver as per your system
# here geckodriver is within anaconda so I write it straight forward
driver=webdriver.Firefox(executable_path='geckodriver')
# calling login function
SoDelhipage(driver)

# %% [markdown]
# #  Ques -> Follow/Unfollow given handle -
#
#     1)Open the Instagram Handle of “So Delhi”
#     2)Start following it. Print a message if you are already following
#     3) After following, unfollow the instagram handle. Print a message if you have already unfollowed.

# %% [markdown]
# # 1 ) Code for open the handle of So Delhi

# %%
# 1) *******open the handle of So Delhi:*******
from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module
#function for login
def SoDelhipage(driver):
    
    # go to instagram login page using .get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people follow you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
    # pass the word "food" in the search box to print the insatgrams handle
    # to locate the search box using the class name of the search box having the class name "XTCLo.x3qfX"
    search_bar=driver.find_element_by_class_name('XTCLo.x3qfX')
    # passing the word "food" in the search box usnig the .send_keys fun
    search_bar.send_keys('So Delhi')
    # wait for some time so that all the handles can be loaded
    time.sleep(2)
    # to get the names of driver 
    # locate the names of insta handle having the class name "Ap253"
    # find the required handle from the search result although its on the top but for worst case
    names=driver.find_elements_by_class_name('Fy4o8')
    for i in names:
        if i.text=='So Delhi':
            # clicking on the handle to open it
            i.click()

# using geckodriver(FireFox web driver name) to remote the window please use the path for geckodriver as per your system
# here geckodriver is within anaconda so I write it straight forward
driver=webdriver.Firefox(executable_path='geckodriver')
# calling login function
SoDelhipage(driver)

# %% [markdown]
# #  2) Code for following the So Delhi profile and print message if alredy followed.

# %%
#2) *****follow it or print alreardy follwed:*****

from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module
#function for login
def followed(driver):
    
    # go to instagram login page using .get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people follow you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
    # pass the word "food" in the search box to print the insatgrams handle
    # to locate the search box using the class name of the search box having the class name "XTCLo.x3qfX"
    search_bar=driver.find_element_by_class_name('XTCLo.x3qfX')
    # passing the word "food" in the search box usnig the .send_keys fun
    search_bar.send_keys('So Delhi')
    # wait for some time so that all the handles can be loaded
    time.sleep(2)
    # to get the names of driver 
    # locate the names of insta handle having the class name "Ap253"
    # find the required handle from the search result although its on the top but for worst case
    names=driver.find_elements_by_class_name('Fy4o8')
    for i in names:
        if i.text=='So Delhi':
            # clicking on the handle to open it
            i.click()
    time.sleep(2)

    

    try:
        follow_button=driver.find_element_by_class_name('_5f5mN.jIbKX._6VtSN.yZn4P')
        follow_button.click()
        print("Followed")
    except NoSuchElementException:
        print('already followed')

driver=webdriver.Firefox(executable_path='geckodriver')
# calling login function
followed(driver)
# Out:
# already followed

# %% [markdown]
# # 3 ) Code for unfollow it or print message

# %%
# #3) code for un-following and print message if alredy un-followed with function:
from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module
#function for login
def unfollowed(driver):
    
    # go to instagram login page using .get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 20 seconds, #
    #which implies the maximum wait time is 10 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    driver.implicitly_wait(5)
    try:
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except:
        NoSuchElementException
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people follow you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
    # pass the word "food" in the search box to print the insatgrams handle
    # to locate the search box using the class name of the search box having the class name "XTCLo.x3qfX"
    search_bar=driver.find_element_by_class_name('XTCLo.x3qfX')
    # passing the word "food" in the search box usnig the .send_keys fun
    search_bar.send_keys('So Delhi')
    # wait for some time so that all the handles can be loaded
    time.sleep(2)
    # to get the names of driver 
    # locate the names of insta handle having the class name "Ap253"
    # find the required handle from the search result although its on the top but for worst case
    names=driver.find_elements_by_class_name('Fy4o8')
    for i in names:
        if i.text=='So Delhi':
            # clicking on the handle to open it
            i.click()
    time.sleep(2)

    # now  to unfollow  we are going to  click the unfollow button which is preent in the html button tag having class name
    #_5f5mN.-fzfL._6VtSN.yZn4P
    try:
        follow_button=driver.find_element_by_class_name('_5f5mN.-fzfL._6VtSN.yZn4P')
        follow_button.click()
        time.sleep(2)
        # click on the unfollow button
        unfollow=driver.find_element_by_class_name('aOOlW.-Cab_')
        unfollow.click()
        print("Un-followed")
    # if it is already unfollowed then their we be no such button therefor an error so handle it and print the message
    except NoSuchElementException:
        print('already un-followed')
        
driver=webdriver.Firefox(executable_path='geckodriver')
# calling login function
unfollowed(driver)
# Out:
# already un-followed

# %% [markdown]
# # Ques 4)  Like/Unlike posts
#
#     1)Liking the top 30 posts of the ‘dilsefoodie'. Print message if you have already liked it.
#     2)Unliking the top 30 posts of the ‘dilsefoodie’. Print message if you have already unliked it.

# %% [markdown]
# #  1) Code for liking the top 30 post of dilsefoodie

# %%
# code for liking the top 30 posts 

from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module
def like(handle_name):
    # h=gi to the instagram handle of the dilsefoodie using the handlename 
    wait = WebDriverWait(driver,10)
    i='https://www.instagram.com/'+ handle_name
    driver.get(i)
    # wait for some time to load the page
    time.sleep(3)
    # innitilize actionChain to automate low level interactions such as mouse movements, mouse button actions, key press,
    actionChain=webdriver.ActionChains(driver)#action chain object
    # scroll the page using the actionChain for uploading the posts 
    for i in range(100):
        actionChain.key_down(Keys.SPACE).key_up(Keys.SPACE).perform()# scrollung the page of dilsefoodie
    # send the control on the top of the page so start from first page
    driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)
    time.sleep(3)
    #made a list to store the href of every post the href are in a tag of div having class = "v1Nh3 kIKUG  _bz0w"
    href = []
    for i in driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG  _bz0w"]/a'):
        # appending the url of post in the list href
        href.append(i.get_attribute('href'))
    print(href)
    # taking the top 30 post from the href list so that they can be liked
    for i in range(30):
        #itrate over the list one by one and take the info of liked or not of the post
        driver.get(href[i])
        # locate the like information
        time.sleep(5)
        like_info =wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="QBdPU "]/*[name()="svg"]'))).get_attribute('aria-label')
        
        time.sleep(5)
        # if the like_info of post is Like then that means you havn't liked the post so like it otherwise print the message 
        if like_info == 'Like':
            time.sleep(2)
            ##  Like the post by clicking on the locate ele of like symbol 
            like=driver.find_element_by_class_name('fr66n')
            like.click()
            # wait for some time
            time.sleep(2)
            # ********* MESSAGE:- if post is liked then print Liked now**********
            print('Photo liked now')
        else:#****** MESSAGE:- if already liked then print the message******
            print('Post number ' + str(i+1) + ' has already been liked')
            
def gethandlename(driver):
    
    # go to instagram login page using .get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('subh7700')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('kyakregarakhkar')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people follow you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
    # pass the word "food" in the search box to print the insatgrams handle
    # to locate the search box using the class name of the search box having the class name "XTCLo.x3qfX"
    search_bar=driver.find_element_by_class_name('XTCLo.x3qfX')
    # passing the word "food" in the search box usnig the .send_keys fun
    search_bar.send_keys('dilsefoodie')
    # wait for some time so that all the handles can be loaded
    time.sleep(2)
    # to get the names of driver 
    # locate the names of insta handle having the class name "Ap253"
    names=driver.find_elements_by_class_name('Ap253')
    # clicking on dilsefoodie 
    for i in names:
        if i.text=='dilsefoodie':
            i.click()
    # taing the handle name of dilsefoodie:
    time.sleep(4)
    handle_name =driver.find_elements_by_xpath('//div[@class="nZSzR"]/h2')
    handle_name_text=handle_name[0].text
    return handle_name_text

# using geckodriver(FireFox web driver name) to remote the window please use the path for geckodriver as per your system
# here geckodriver is within anaconda so I write it straight forward
driver=webdriver.Firefox(executable_path='geckodriver')
# calling login function
handle_name_text=gethandlename(driver)
like(handle_name_text)
# Out:
# ['https://www.instagram.com/p/CFhOd_PH68j/', 'https://www.instagram.com/p/CFgf7g5nFjH/', 'https://www.instagram.com/p/CFcUXaKHyJe/', 'https://www.instagram.com/p/CFb34R7n-yI/', 'https://www.instagram.com/p/CFZsG3EH-bJ/', 'https://www.instagram.com/p/CFW3RtAH96Y/', 'https://www.instagram.com/p/CFWcZ3bHTJk/', 'https://www.instagram.com/p/CFUd2utnAVX/', 'https://www.instagram.com/p/CFToY1ZnQdz/', 'https://www.instagram.com/p/CFR5LD1HHxL/', 'https://www.instagram.com/p/CFRkG4SnG00/', 'https://www.instagram.com/p/CFPlE2lnUy7/', 'https://www.instagram.com/p/CFOryEgHQQv/', 'https://www.instagram.com/p/CFNZpfvno1N/', 'https://www.instagram.com/p/CFM8nALjBPf/', 'https://www.instagram.com/p/CFMJRKQjAFg/', 'https://www.instagram.com/p/CFKMxbUHygW/', 'https://www.instagram.com/p/CFH1vmUHKR3/', 'https://www.instagram.com/p/CFHKPY0jr9x/', 'https://www.instagram.com/p/CFG2ac-jNc5/', 'https://www.instagram.com/p/CFFG6gmDUwH/', 'https://www.instagram.com/p/CFEdogIjdGO/', 'https://www.instagram.com/p/CFCEdEpjuIt/', 'https://www.instagram.com/p/CE_54ijjufk/', 'https://www.instagram.com/p/CE_jPgwDjvJ/', 'https://www.instagram.com/p/CE9sfoYDm1x/', 'https://www.instagram.com/p/CE8pFIhDiHA/', 'https://www.instagram.com/p/CE6LaduDQu6/', 'https://www.instagram.com/p/CE57TkgDq-6/', 'https://www.instagram.com/p/CE4bAlNHKtA/', 'https://www.instagram.com/p/CE3ghvynnos/', 'https://www.instagram.com/p/CE1fj3AHdsN/', 'https://www.instagram.com/p/CE0-uJ-HnmO/']
# Post number 1 has already been liked
# Post number 2 has already been liked
# Post number 3 has already been liked
# Post number 4 has already been liked
# Post number 5 has already been liked
# Post number 6 has already been liked
# Post number 7 has already been liked
# Post number 8 has already been liked
# Post number 9 has already been liked
# Post number 10 has already been liked
# Post number 11 has already been liked
# Post number 12 has already been liked
# Post number 13 has already been liked
# Post number 14 has already been liked
# Post number 15 has already been liked
# Post number 16 has already been liked
# Post number 17 has already been liked
# Post number 18 has already been liked
# Post number 19 has already been liked
# Post number 20 has already been liked
# Post number 21 has already been liked
# Post number 22 has already been liked
# Post number 23 has already been liked
# Post number 24 has already been liked
# Post number 25 has already been liked
# Post number 26 has already been liked
# Post number 27 has already been liked
# Post number 28 has already been liked
# Post number 29 has already been liked
# Post number 30 has already been liked

# %% [markdown]
# #  2) Code for Un-liking the top 30 post

# %%
# code for un-liking the top 30 posts 

from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module
def unlike(handle_name):
    # go to the instagram handle of the dilsefoodie using the handlename 
    wait = WebDriverWait(driver,10)
    i='https://www.instagram.com/'+ handle_name
    driver.get(i)
    # wait for some time to load the page
    time.sleep(3)
    # innitilize actionChain to automate low level interactions such as mouse movements, mouse button actions, key press,
    actionChain=webdriver.ActionChains(driver)#action chain object
    # scroll the page using the actionChain for uploading the posts 
    for i in range(100):
        actionChain.key_down(Keys.SPACE).key_up(Keys.SPACE).perform()# scrollung the page of dilsefoodie
    # send the control on the top of the page so that start form the first page
    driver.find_element_by_tag_name('body').send_keys(Keys.CONTROL + Keys.HOME)
    time.sleep(3)
    #made a list to store the href of every post the href are in a tag of div having class = "v1Nh3 kIKUG  _bz0w"
    href = []
    for i in driver.find_elements_by_xpath('//div[@class="v1Nh3 kIKUG  _bz0w"]/a'):
        # appending the url of post in the list href
        href.append(i.get_attribute('href'))
        
    # taking the top 30 post from the href list so that they can be unliked
    for i in range(30):
        #itrate over the list one by one and take the info of liked or not of the post
        driver.get(href[i])
        # locate the unlike information
        unlike_info = wait.until(EC.presence_of_element_located((By.XPATH,'//div[@class="eo2As "]/section[1]/span[1]/button/*[name()="svg"]'))).get_attribute('aria-label')
        
        time.sleep(3)
        # if the unlike_info of post is Unlike then that means you havn't unliked the post so unlike it otherwise print the message 
        if unlike_info == 'Unlike':
            time.sleep(2)
            ##  Unlike the post by clicking on the locate ele of like symbol 
            unlike=driver.find_element_by_xpath('//div[@class="eo2As "]/section[1]/span[1]/button')
            unlike.click()
            # wait for some time
            time.sleep(2)
            # *********MESSAGE:- if post is liked then print unliked now******
            print('Photo unliked now')
        else:# ***** MESSAGE:- if already liked then print the message*******
            print('Post number ' + str(i+1) + ' has already been unliked')
            
def gethandlename(driver):
    
    # go to instagram login page using .get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people follow you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
    # pass the word "food" in the search box to print the insatgrams handle
    # to locate the search box using the class name of the search box having the class name "XTCLo.x3qfX"
    search_bar=driver.find_element_by_class_name('XTCLo.x3qfX')
    # passing the word "food" in the search box usnig the .send_keys fun
    search_bar.send_keys('dilsefoodie')
    # wait for some time so that all the handles can be loaded
    time.sleep(2)
    # to get the names of driver 
    # locate the names of insta handle having the class name "Ap253"
    names=driver.find_elements_by_class_name('Ap253')
    # clicking on dilsefoodie 
    for i in names:
        if i.text=='dilsefoodie':
            i.click()
    # taing the handle name of dilsefoodie:
    time.sleep(4)
    handle_name =driver.find_elements_by_xpath('//div[@class="nZSzR"]/h2')
    handle_name_text=handle_name[0].text
    return handle_name_text

# using geckodriver(FireFox web driver name) to remote the window please use the path for geckodriver as per your system
# here geckodriver is within anaconda so I write it straight forward
driver=webdriver.Firefox(executable_path='geckodriver')
# calling login function
handle_name_text=gethandlename(driver)
unlike(handle_name_text)
# Out:
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Post number 4 has already been unliked
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now
# Photo unliked now

# %% [markdown]
# # Ques : Extract list of followers
#
#     1) Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.
#     2) Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.

# %% [markdown]
# #  1) Code for list of top 500 followers of foodtalkindia and sodelhi

# %%
# 1) Extract the usernames of the first 500 followers of ‘foodtalkindia’ and ‘sodelhi’.  

from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module

def login(driver):
    # go to instagram login page using get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people follow you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
def followers(instahandle):
    # send get reuest to the insta handle of which followers has to scrape
    wait = WebDriverWait(driver,10)
    i='https://www.instagram.com/'+ instahandle
    
    driver.get(i)# get request
    #wait so page loaded completely
    time.sleep(3)
    # click the list of all the followers having under the tag ul of class k9GMp
    follower=driver.find_element_by_xpath('//ul[@class="k9GMp "]/li[2]/a')
    follower.click()# clicking on the list of followers
    time.sleep(2)
    # locate the usernames of the followers
    followers_usernames_list = driver.find_element_by_xpath('//div[@class="isgrP"]/ul')
    # click the usernames
    followers_usernames_list.click()
    # scroll the page using the actionchain
    actionChain = webdriver.ActionChains(driver)# action object
    for i in range(200):# scrolling so that 500 followers can be loaded
            actionChain.key_down(Keys.SPACE).key_up(Keys.SPACE).perform()
    # made alist of the followers
    follower_name = []
    # locate the usenames of the followers which are under the tag li
    for username in followers_usernames_list.find_elements_by_tag_name('li'):
            # taking the tile ie username and append them into the list
            usernames = username.find_element_by_class_name('FPmhX ').get_attribute('title')
            follower_name.append(usernames)
            #only top 500
            if (len(follower_name) == 500):
                break
    # return the list of usernmaes
    return follower_name
# using geckodriver(FireFox web driver name) to remote the window please use the path for geckodriver as per your system
# here geckodriver is within anaconda so I write it straight forward
driver=webdriver.Firefox(executable_path='geckodriver')
# calling the login fun to log in
login(driver)
# insta handles of which follwers need to be extract
a=['foodtalkindia','sodelhi']
# calling the followers function
for i in a:
    print("Top 500 followers of",i,"are:")
    print()
    print(followers(i))
# Out:
# Top 500 followers of foodtalkindia are:
#
# ['kirat__13', '_rahul_j_p_', 'theawakeningbysonicasingh', '_kiruba_2510', 'rahul.raiput.3118', 'nils_7767', 'sonugautamtalera', 'jvkhatri', 'findingzen_', 'kiartkitchen', 'artworksbackup', 'cookingworld4', 'dragonboxdelivers', 'farmly.in', 'smyh_lswdny', 'tonguetastee', '_.04__sapna', 'thomasabraham12', 'pragya_g_97', 'bigeater_bipro', 'nabi_l_travel', 'call.me.pals', 'morrismurray6', 'preetisharma7538', '_njl.33', 'bachpandeoria', 'das369033', 'ankitmalviya312gemil.com7', 'kunal_sharma21_', 'cookiecutter_mumbai', 'rahul_adulkar', 'theperfectintro', 'fashion__4__art', 'malcolm_mascarenhas', 'pelican.express', 'nazykitchens', 'foodtherapy_nikita', 'pan_apron', 'you_come_here_often_', 'hungrysoul25', 'anki_si_', 'indian__foodies_love', 'yashmurmuria', 'journey_indianadventure', 'i_him_and_mountains', 'nilofer.e', 'the.sarfiri.girl', 'suba.saurovi', '_food_paradisee', 'bhawna_masson142105', 'kumarshanu000019', 'mihika_1309', 'coolest_cute_b0y', 'ruchika_shakya', 'feelingsonplatter', 'mr._jagirdar__', 'henal__kasturi', 'k_a_i_f_5', 'sumitjindal6730', 'kanu_1684', 'va1usa', 'fineherbspices', 'dio_kid_34', 'aj_the_heart_hacker_', 'lakshmipraba03', 'mariyadarakshan', 'vettaiyan._vetty', '_.thefoodjunction._', 'updatingtrends', 'sunny.emotion.5', 'sandra_secahya', '1927___fatima', '123rmeena', 'r_j_writings', 'blogwithjapnoor', '_craving_hut_', 'ki.shore6221', 'itiskamal', 'foodies__97', 'neha_holistic', 'foodtechnologyquiz20', 'ayeshashareef12', 'foodarthospitality', 'shefali_adithya', 'owaiskhan__', 'deliciousdiary_ds', 'the_hobby_feed', 'the__kitchen_cinema', 'aish.2629', 'akanksha006', 'muhammad_hamdhan_', 'chef.suraj_kumar', 'dahi_dalchini', 'roundglassthali', 'its_ms_gauri_shukla', 'shaifalinagpalmua', 'leenasingh97', 'foodgourmet__', 'mealsformysoul', 'manavvv__007', 'jasmine_makeup_artist7989', 'foodiesonlyplease', 'slumbercucumbeer', 'healthyfoodoholics', 'sanjana_11_02', 'sudheer.sudheer.sudhi490', 'kavs30', 'milymandal', 'ayushi.gupta00', 'kenps2842003', 'kalpana.ashokkumar', 'foodieck', 'foodfoodiesmagic', 'klick_n_blink', 'fitnessnikita', 'veggie_vysh', 'foodeeslife', 'bitcrunchy', 'cooking_dailyy', 'adorableaaravi', 'kakde4124', 'chatori_jeebh_', 'aizat__peri', 'varungrover8421', 'sonali.malik12', 'kamya711', 'neerajyadav814', 'theoliveroute', 'sarthakmanu', 'sunita_punjabi_kitchen', 'ansumaanpanda', 'the_bongfoodie', 'spitensils', 'vab_choudhary', 'animo_collective', 'food_jet_', 'clickalmost', 'the.foodweb', 'ahluwaliaankit786', 'food_tales_atreyee_', 'iamgraphicman', 'thecaloriekitchens', 'andherifoodjunctionn', 'madhuraskitchen', 'aditi_nem', 'debjani1202', 'mohit.rathour_', 'i.nooorii', 'thehousewives8', 'shaily03', 'vinay.sunet', 'ustadjattpb10', 'pyassikutiya69_', 'cook_with_jindu_', 'explore.beautyof.india', 'nostalgicart._', 'india_envo_creativity', 'vaishnavisingh_rathore7', 'creative_._cuisine', 'she_van_e', 'ashnanagpal', 'arpan_96', 'deeptikewlani', 'home_cravings_', 'weni.abdillah', 'cheena.b', 'khankshahrukh', 'cook_with_benorita', 'legalassistancegurgaon', 'shreya.a.kapoor', 'foodjourneybypritam', 'shad_shahjahan', 'amarpreetkkaur', 'biryani_darbar_indore', 'nosh_goodmoodfood', 'basnt.88', 'gharkazaika_indianfood', 'lsd.entertainment', 'kangscookingcorner', 'spice_sprinkles', 'foodcraze95', 'nikhil.bhatt_', 'raghavhans', 'healthyandeliciousfood', 'theoryofmadhav', '__food__hub', 'de_fine_', 'ek.gumnam.shayar', 'yashaswinishivaramaiah', 'rafiq_687', 'tharanisharma3', 'jainbhanvi', 'hi.nd8667', 'priyanka_thukral', 'japneetbahra', 'refectionsthejuicebar', 'desert_on_top', 'indian_cuisines12', 'kuttyes_restaurent', 'themasalaco', 'monu_naagar7', 'terriblytraveltales', 'shreeji_packaging', 'suesyogikettle', 'the_hungryfriends', '_engineer__baba', 'vikas.khosla7', 'manisha4221', 'aanchal3431', 'lokesh_aradhya_m', 'serrobinstark', 'food_quest_12', 'two_everywhereist', 'foodie_duddy_', 'thefoodieebffs', 'healthybodiez_farheenhamidani', 'suresh_agar', 'mo._diab', 'chatore_company', 'nehasolanki_215', 'manpreet_kri ...
# Top 500 followers of sodelhi are:
# ['sameerkhan_xxo', 'superlative_rishabh', 'beingrajvanshi', 'mrbajaj08', 'thebutterflyroom14', 'my_fooood_journey', 'kartik.kothari_', 'brown_starboy_', 'kritijain.16', 'choudharyvardhan', 'dosageofart', 'ishaan.pandey', 'anindiita__', 'bakloll_memes', 'pappimachhiwala', 'vicky.sharma.921', 'salmankhanfan.2143', 'kiartkitchen', 'foodiegenics', 'robnsingh', 'the.cuisinebox', 'gurjasraheja09', 'piyushdutt13', 'rani___sharma__', 'butter___parantha', '_aditya1039', 'vegg.ietummy', 'indian_foodexplore', 'akshitamaheshwarii', 'share.xperience', 'teenymeenymasters', 'acompletebrash', 'aartharmassey', 'vimal_4988', 'aasthaa.gabaa', 'rishika_here', 'facestorybymegha', 'rahul.rs44', 'divya_thakur1508', 'arushibhel', 'lost_guy_journey', 'dewangan1429', 'shaloo.bhat.7', 'kanjwani_amit', 'nitisha_k_chauhan', 'nitanshmendiratta', 'trabangineer', 'deepraman047', 'richagrover08', 'foodie.flab', 's_singhh__', 'eatn.art', '_.niks__', 'biuttudasgmail.com6879', 'mr.mannu30', 'delhifacts', 'abhishek.bhatt99', 'vandanaakapoor7', 'classic_makeover_sangya', 'rewaliak', 'agrawal_rakshita', 'b3abrand', 'shanumati_ki_rasoi', 'priya_kashyap_07', 'starstruckwonderman', 'shahbu_official_', 'stupid.zayn', 'bhenkayoda', 'the_indi_world', 'iamalokranjan', 'ssakshi55_.pvt', 'only_one_angel_and_im_no.1', 'iam.akshatverma', 'rohankshetry1', 'tanzeempatankar', 'zahrafreedman', 'shanaaya.sharmaaa', 'apna.111', 'shubhangilohia', 'path_of_wellness', 'posterhookdotcom', 'meghna8595', 'tinywildlife', 'emailsubia25', 'teekhiduniya', 'shahipaneeer', 'chakshaysingh26____', 'moni.rodriques', 'eat_with_uneeb', 'visit.hyderabad', 'lilaveyesil', 'inher_paradise', 'alostsoul10', 'adancingengineer', 'samir_s_a1', 'thuptanyma11', 'iam_ankurgupta', 'karan675', 'delicioustiffinservices', 'raghavsharmamat', 'saurabh_mishragooner', 'a_dish_a_day_', 'abhishek_d_', 'i.adityagupta', 'insane_foodie_', 'bucketlistt.in', 'its_all_about_beingpositive', 'that_foodie_sona', 'rawnak2.0', 'praty_12', 'tami.laatamilaa', '_monaya_ahmed_', 'terre.pure', 'aisha.0442', 'food_talk23', 'preetirana5819', 'foobey_', 'aparna_sawan_pradhan', 'iamssiddiqui', '_spiceart', 'shivani_345254', 're_loaded_u', 'roopka_chikan', 'tarunudawat', '_simeeeee_18', 'shubhami_01', 'foodengineerofficial', 'foodandmore96', '__ihe___', 'lifeecruiser', 'kanishq_basoya_dellhii0001', 'nswtravelogue', 'muskaan_pachisia', 'kanchan.gidwani', 'sandeep_jangra56', 'dat.shawtyxx', 'aanchal.yogi2006', 'blogwithjapnoor', 'shivjii2020', 'aishwaryaissar', 'divyanshmishra980', 'cookwithekta', 'shivanikohli15', 's_k_maddy', 'divya_surve22', 'stargazing_hooman_', 'mist.of.apathy', 'sibas_sinha', '_soulful_sentiments_', 'drxpharmacist_ajay_kumar', 'eleena_aeren', 'beenakashyap020', 'rehan_ansari_smart_boy_', 'smart_jat', 'x2anime_', 'the.ultimate_palette', 'medicomind96', 'desiexplorerr', 'shiv_roka', 'carryionai', 'heenaprashar', 'craftizerzstore', '________anuj_______', 'arpit.upadhyay01', 'gk1212121', 'newdelhiblogger', 'shorshe_phool', 'simpy_yadav_27', 'thehayatfood_', 'akriti3887', 'go4lifenow', 'madnomadgirl', 'krishsingh_25', 'raaghavmehta', 'drtankkr', 'theproud_glutton', 'anujain8080', 'bhimsainsbengalisweet', 'pashi.pashi.560', 'kritika.m11', '__tejasva__tyagi__', 'ishta___', 'shanumahor1995', 'arpitdang', 'masoombaccha2020', 'honest.meal', 'abhayfalwaria', 'nishuudubeyy', 'iamsrishtibhagat', 'foodierishie', 'tanya__pandey_28', 'lakshita.sharma.509', '_vivid_me__', 'flavours_from_my_kitchen', 'riyalaghari11', 'shivani15singh', '_meet_u_soon', 'the.arnav', 'perhapsaschemer', 'thefoodieindori', 'gourav.chhabra.1', 'imanoj_06', 'vaishhshukla', 'singha_saahil', 'mdsakeel5', '_manali_singh__', 'rollnd_blues', 'tusha_r4578', 'aman_khan509', 'thefoodiespace_', 'alia_varun_lover', 'ronikagrover', 'jasprit_26', 's.w.e.e.t.r.i.s.h.i', 'southdelhichick', 'kavya__90', 'shim_vashist', 'chindimaanush', 'ansari_shadan.786', 'meenunavinsharma', 'vansh251', 'gulshan_kumar_sing1', 'bhooms.pvtttt', 'chococrunch_delight', 'saubhagya_aa', 'kakde4124' ...

# %% [markdown]
# # 2)  Code for print all the followers of Foodtalkindia that you follow but they dont follow you..

# %%
# 2) Now print all the followers of “foodtalkindia” that you are following but those who don’t follow you.


from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module

def login(driver):
    # go to instagram login page using get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people followfollowers of “foodtalkindia” that you are following but those who don’t follow you you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
# function for the followers of “foodtalkindia” that you are following but those who don’t follow you
def non_followers_mine(instahandle):
    # send the get request to the foodtalkindia
    wait = WebDriverWait(driver,10)
    i='https://www.instagram.com/'+ instahandle
    
    driver.get(i)
    # wait for loading the page
    time.sleep(3)
    # click on the list of mutually followed by instahandles for dilsefoodie (having the class "tc8A9") 
    try:
        mutual_list=driver.find_element_by_class_name('tc8A9')
        mutual_list.click()
        # of their is no such list ie no mutual follwed by list
    except NoSuchElementException:
        print("NO mutual follwers with",instahandle)
        return
    
    time.sleep(2)
    # get all the follower of the instahadle ie foodtalkindia and pick only mutual followed by ones:
    See_all_followers=driver.find_element_by_xpath('//div[@class="SfPzb"]/a').click() #to see all the list
    # ittrating on all the followers list:
    all_follower=driver.find_element_by_xpath('//div[@class="isgrP"]/ul')
    all_follower.click()
    # now  for scroll the list of all followers initiate action chain:
    actionChain = webdriver.ActionChains(driver)# action object
    # len of all follers  of the dilsefoodie and mutually followed by (Without scrolling the page)
    len_all_followers_loadedwithoutscrolling=len(all_follower.find_elements_by_css_selector('li'))
    len_mutual_followers_loadedwithoutscrolling=len(all_follower.find_elements_by_class_name('_8A5w5'))
    
    
    # load all the mutually follwed by list ie those who follow dilsefoodie and I also follow them
    while len_all_followers_loadedwithoutscrolling<len_mutual_followers_loadedwithoutscrolling:
        actionChain.key_down(Keys.SPACE).key_up(Keys.SPACE).perform()
        len_all_followers_loadedwithoutscrolling=len(all_follower.find_elements_by_css_selector('li'))
        
    # lets get the usernames of all the mutual followers:
    mutual_followers=[]
    for username in all_follower.find_elements_by_tag_name('li'):
        try:
            # lets first get all the usernames which are follwing the foodtalkindia and you follow them(using the class name _8A5w5)
            follwing_users=username.find_element_by_class_name('_8A5w5')
            # now lets get their usrnames byb using the tag title
            usernames = username.find_element_by_class_name('FPmhX ').get_attribute('title')
            # yeh hai mutual usernames 
            mutual_followers.append(usernames)
        except:
            # agr voh mutual na hai toh unko use nhi karna but we have to handle the error because of them
            NoSuchElementException
            
    
   
    
    ## now the turn is to find the users who are following me and then we'll cross check over them to know who follows me as
    #well as foodtalkindia (offcousrse whom I follow)
    time.sleep(3)
    # back on the page of instagram
    driver.back()
    driver.back()
    # going on the profile to extract the my follower using the xpath 
    profile=driver.find_element_by_xpath('//a[@class="_2dbep qNELH kIKUG"]').click()
    # wait for  loading the profile page 
    time.sleep(3)
    # no of total instal handle follows me
    total_follower_mine=driver.find_element_by_xpath('//ul[@class="k9GMp "]/li[2]/a')
    total_follower_mine_len=int(float(total_follower_mine.find_element_by_class_name('g47SY ').text))
    # opening the list of the followers
    my_followers_list_open=driver.find_element_by_xpath('//ul[@class="k9GMp "]/li[2]/a').click()
    # click on my_follwers list
    my_followers_list_click=driver.find_element_by_xpath('//div[@class="isgrP"]/ul')
    my_followers_list_click.click()
    # # scroll the page using the actionchain so that all the lsit of my_followers can be extract
    actionChain = webdriver.ActionChains(driver)# action object
    # len of the list of my_followers without scrolling the list
    len_my_followers_list_click_loadedwithoutscrolling=len(my_followers_list_click.find_elements_by_css_selector('li'))
    # scrolling the list until all the follwers can be alble to extract(aabhi sirf len lege total ki)
    while len_my_followers_list_click_loadedwithoutscrolling<total_follower_mine_len:
        actionChain.key_down(Keys.SPACE).key_up(Keys.SPACE).perform()
        len_my_followers_list_click_loadedwithoutscrolling=len(my_followers_list_click.find_elements_by_css_selector('li'))
        time.sleep(2)
    # getting list of followers of mine:
    
    follower_name_mine = []
    for username in my_followers_list_click.find_elements_by_tag_name('li'):
        # getting their usrname using the class name 
            usernames = username.find_element_by_class_name('FPmhX ').get_attribute('title')
            follower_name_mine.append(usernames)
            
    
    # followers of foodtalkindia whom i follow but they didn't follow me back:
    for i in mutual_followers:
        if i not in follower_name_mine:
            
            #the followers of “foodtalkindia” that you are following but those who don’t follow you
            print(i)
# using geckodriver(FireFox web driver name) to remote the window please use the path for geckodriver as per your system
# here geckodriver is within anaconda so I write it straight forward
driver=webdriver.Firefox(executable_path='geckodriver')
# log in to insta
login(driver)
# followers of “foodtalkindia” that you are following but those who don’t follow you
non_followers_mine('foodtalkindia')
# Out:
# foodi_eshoodie
# _cuisine_india_

# %% [markdown]
# # QUES: Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly -
#
#     1)If You have already seen the story.
#     2)Or The user has no story.
#     3)Or View the story if not yet seen.

# %% [markdown]
# #  Code for check the story if CN

# %%
# Code to check the story of ‘coding.ninjas’.the story of ‘coding.ninjas’.

from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module

def login(driver):
    # go to instagram login page using get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people followfollowers of “foodtalkindia” that you are following but those who don’t follow you you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
# function for the story seen or not or not posted

def story(instahandle):
     # send the get request to the coding.ninjas
    wait = WebDriverWait(driver,10)
    i='https://www.instagram.com/'+ instahandle
    
    driver.get(i)
    # wait for loading the page
    time.sleep(3)
    # if their is an story then print either view story or alredy seen
    try:
        # to locate the story
        stories=driver.find_element_by_css_selector('div.XjzKX div canvas')
        # if already seen
        if stories.get_attribute('height')=='166':
            return ("You have already seen the story.")
        else:
            return ("View the story")
    # in case of no story
    except NoSuchElementException:
        return ("No story uploaded")
driver=webdriver.Firefox(executable_path='geckodriver')
# log in to insta
login(driver)
print(story('coding.ninjas'))
# Out:
# View the story

# %% [markdown]
# #  Code for check the story of CN ( This code will work in case you have followed the insta handle of CN if not use the above code)

# %%
# code for Check the story of ‘coding.ninjas’. Consider the following Scenarios and print error messages accordingly
# note:- This code is when you have followed the coding.ninjas 

from selenium import webdriver #The selenium.webdriver module provides all the WebDriver implementationsm,This allow us to control browser with our code
from selenium.webdriver.support.ui import WebDriverWait# files for providing waits
from selenium.webdriver.support import expected_conditions as EC# to provide the explicit wait (conditon)
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains#ActionChains are a way to automate low level interactions such as mouse movements, mouse button actions, key press
from selenium.webdriver.common.keys import Keys# This Keys class provide keys in the keyboard
import time# Importing the time 
from selenium.common.exceptions import NoSuchElementException# import nosuchelementexception module

def login(driver):
    # go to instagram login page using get request
    driver.get('https://www.instagram.com/')
    # wait for some time for loading page
    time.sleep(2)
    # passing the username in the the text-box for username(This text-box has name->username so I'm using this to locate the text-box)
    username=driver.find_element_by_name('username').send_keys('sample_username')# pass the user handle name or email or mobile no(for that i used .send_keys)
    # passing the password in the the text-box for password(This text-box has name->password so I'm using this to locate the text-box)
    password=driver.find_element_by_name('password').send_keys('sample_password')# pass the password(for that i used .send_keys)
    # now need to click on login button to login and this is of type submit so used .submit to click over it
    Login_button=driver.find_element_by_class_name('sqdOP.L3NKy.y3zKF').submit()#class name for login button was  "sqdOP.L3NKy.y3zKF" so i used that
    # wait for some time to completely load the page here i used implicit wait I have given Implicit Wait as 5 seconds, #
    #which implies the maximum wait time is 5 seconds for the particular element to load or to arrive at the output
    # means agr phle output aagya tho wait nhi krega yeh
    
    driver.implicitly_wait(5)
    # as You login their comes a pop up saying whether you want to save the details or not Here we are 
    # handling this by clicking on not now button
    try:# if this pop up comes click on not now
        save_login_info=driver.find_element_by_xpath('//div[@class="cmbtv"]/button').click()
    except NoSuchElementException:# if no such pop-up open then pass (I'm doing this because some time this pop up doesnt came)
        pass
    # wait for some time to load the page 
    driver.implicitly_wait(10)
    # ek notification aa rhi hai as you login :-"Turn on Notifications Know right away when people followfollowers of “foodtalkindia” that you are following but those who don’t follow you you or like and comment on your photos."
    # thi Extra_notification_handle is to handle that extra notification
    Extra_notification_handle=driver.find_element_by_class_name('aOOlW.HoLwm ')#aOOlW   HoLwm is the class name for cancle button of notification 
    Extra_notification_handle.click()# bacuse the cancle button is not of submit type so I had to click
    time.sleep(2)# wait for 2 sec
# function for the story seen or not or not posted
def story(login):
    # get the list of all the storespost by handle you followed from the login page
    
    
    # list of the stories 
    story_list=stories.find_elements_by_css_selector('li.Ckrof')
    # itrate over the list of stories and check if their is the story of coding.ninjas
    for i in story_list:
            # if their is the story of coding.ninjas
            if (i.text)=='coding.ninjas':
                # find the height of the story of coding.ninjas which is under the canvas tag
                a=i.find_element_by_css_selector('canvas.CfWVH')
                # if height is 64 ie you have seen the story otherwise you haven't
                if a.get_attribute('height')=='64':
                    return ("You have already seen the story.")
                else:
                    return ("View the story")
    # if their is not any story posted            
    return ("No story posted")

# using geckodriver(FireFox web driver name) to remote the window please use the path for geckodriver as per your system
# here geckodriver is within anaconda so I write it straight forward         
driver=webdriver.Firefox(executable_path='geckodriver')
# login to instagram
a=login(driver)
# calling the finction
r=story(a)
print(r)
# Out:
# View the story
